# %% [markdown]
# # Dataset Description

# %% [markdown]
# World Happiness Report:
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# generally the happyness score and rank depends on the following column--
# 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape  #checking the data dimension
# Out:
# (158, 12)

# %% [markdown]
# we have 158 rows and 12 columns in our dataset

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [raw]
# first 2 columns are of object type ..so we may need to label encode them or may be drop them later

# %%
#checking if there is any null values in the dataset
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Therefore there are no null values in the data set

# %%
df.describe()  #checking the statistical summery
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
# Lets label encode the first 3 columns --country, region

from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
df_new=df.copy()

# %%
df_new
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
for col in ['Country','Region']:
    
    df_new[col] = le.fit_transform(df_new[col])
 
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# 5         45       9               6            7.406         0.03140
# 6         99       9               7            7.378         0.02799
# 7        134       9               8            7.364         0.03157
# 8        100       0               9            7.286         0.03371
# 9          6       0              10            7.284         0.04083
# 10        64       4              11            7.278         0.03470
# 11        33       3              12            7.226         0.04454
# ...

# %% [markdown]
# # now we can check for the outliers in the columns

# %%
df_new.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  there is no significant outliers in the data set, so lets not remove any outliers from the data set.

# %%
#now lets check the correlation between the columns using heat map
plt.figure(figsize=(12,7))
sns.heatmap(df_new.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#checking correlation with respect to target column
corr_matrix=df_new.corr()
corr_matrix['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Country                          0.083380
# Region                          -0.176791
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Here Economy(GDP per Capita),Family,Health(Life Expectancy) are highly correlated with Happiness Score

# %%
#splitting the independent and target variable in x and y
x=df_new.drop('Happiness Score',axis=1)
y=df_new['Happiness Score']

# %% [markdown]
# Now visualisation of the dataset using some plots

# %%
#univariate analysis
for i in x.columns:
    plt.figure()
    sns.distplot(x[i])

# %%
#checking the skewness

# %%
x.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# we can see some skewness in some columns,so we can use power_transform to remove them

# %%
from sklearn.preprocessing import power_transform

# %% [markdown]
# Here I have a question.
# Do I need to powertranform the columns country,region,happiness rank? because they are of categorical type.If no,then how can I powertransform rest of the columns?

# %%
x1=x.copy()

# %%
x1.shape
# Out:
# (158, 11)

# %%
columns=['Standard Error','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity']

# %%
for i in columns:
    z=x1[i].values.reshape(-1,1)
    z1=power_transform(z)
    x1[i]=pd.DataFrame(z1)

# %%
#After powertranfrom checking skewness again
x1.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Standard Error                  -0.020092
# Economy (GDP per Capita)        -0.317575
# Family                          -0.169651
# Health (Life Expectancy)        -0.183181
# Freedom                         -0.080728
# Trust (Government Corruption)    0.185965
# Generosity                       0.013320
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#univariate analysis
for i in x1.columns:
    plt.figure()
    sns.distplot(x1[i])

# %%
#therefore skewness has been removed

# %%
x1.describe()
# Out:
#           Country      Region  Happiness Rank  Standard Error  \
# count  158.000000  158.000000      158.000000    1.580000e+02
# mean    78.500000    5.120253       79.493671    7.364011e-16
# std     45.754781    2.993321       45.754363    1.003180e+00
# min      0.000000    0.000000        1.000000   -3.090112e+00
# 25%     39.250000    3.000000       40.250000   -6.497765e-01
# 50%     78.500000    4.500000       79.500000   -5.810529e-02
# 75%    117.750000    8.000000      118.750000    5.393874e-01
# max    157.000000    9.000000      158.000000    2.586272e+00
#
#        Economy (GDP per Capita)        Family  Health (Life Expectancy)  \
# count                158.000000  1.580000e+02              1.580000e+02
# mean                   0.846137 -6.464590e-17             -3.021493e-16
# std                    0.403121  1.003180e+00              1.003180e+00
# min                    0.000000 -2.276295e+00             -1.971089e+00
# ...

# %%
#As the range(max-min) varies theoughout the columns of the dataset,so we have to scale the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x2=sc.fit_transform(x1)
x2=pd.DataFrame(x2,columns=x1.columns)

# %%
x2.head()
# Out:
#     Country    Region  Happiness Rank  Standard Error  \
# 0  1.238770  1.300256       -1.721000       -0.972226
# 1 -0.449465  1.300256       -1.699075        0.309350
# 2 -0.909893  1.300256       -1.677149       -1.062017
# 3  0.581016  1.300256       -1.655224       -0.503610
# 4 -1.194920 -0.040302       -1.633299       -0.823548
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.369621  1.669206                  1.491765  1.756335
# 1                  1.135226  2.012132                  1.532348  1.439946
# 2                  1.192861  1.739586                  1.085223  1.615733
# 3                  1.525130  1.553118                  1.147600  1.792821
# 4                  1.194876  1.501726                  1.270179  1.475479
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                       1.773991    0.622391           0.758258
# 1                       0.315993    1.480995           1.092857
# ...

# %%
x2.describe()
# Out:
#             Country        Region  Happiness Rank  Standard Error  \
# count  1.580000e+02  1.580000e+02    1.580000e+02    1.580000e+02
# mean   1.264811e-17 -1.545880e-17    5.902452e-17   -1.686415e-17
# std    1.003180e+00  1.003180e+00    1.003180e+00    1.003180e+00
# min   -1.721123e+00 -1.715998e+00   -1.721000e+00   -3.090112e+00
# 25%   -8.605615e-01 -7.105803e-01   -8.604306e-01   -6.497765e-01
# 50%    0.000000e+00 -2.078713e-01    1.387679e-04   -5.810529e-02
# 75%    8.605615e-01  9.651166e-01    8.607081e-01    5.393874e-01
# max    1.721123e+00  1.300256e+00    1.721277e+00    2.586272e+00
#
#        Economy (GDP per Capita)        Family  Health (Life Expectancy)  \
# count              1.580000e+02  1.580000e+02              1.580000e+02
# mean              -3.414990e-16 -2.332874e-16              4.356571e-17
# std                1.003180e+00  1.003180e+00              1.003180e+00
# min               -2.105641e+00 -2.276295e+00             -1.971089e+00
# ...

# %% [markdown]
# Here target column is the happiness score column,therefore it is a type of regression problem as happiness score column contain all continuous value

# %% [markdown]
# # Finding the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxscore=0
maxrs=0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x2, y, test_size=0.30, random_state=i)
    lm=LinearRegression()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    score=r2_score(y_test,pred)
    if score>maxscore:
        maxscore=score
        maxrs=i

print('Best Accuracy is',maxscore,'on random state',maxrs)
# Out:
# Best Accuracy is 0.9975662200058767 on random state 124

# %% [markdown]
# We have found best random_state as 124.We will create our train_test_split using this random_state(124)

# %% [markdown]
# # Creating train_test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x2, y, test_size=0.30, random_state=124)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
score=lm.score(x_train,y_train)
print('score:',score)
print('\n')
print('coefficient:',lm.coef_)
print('\n')
print('intercept:',lm.intercept_)
# Out:
# score: 0.9943246528658918
#
#
# coefficient: [ 0.00687492 -0.01571253 -0.27975362 -0.00582449  0.31237216  0.21104428
#   0.17278104  0.1045395   0.07935216  0.10044012  0.40838547]
#
#
# intercept: 5.370741521343431

# %%
#predicing the target value
pred=lm.predict(x_test)

# %%
#compared predicted value and actual value
print('Predicted value and Actual value',pred,y_test)
# Out:
# Predicted value and Actual value [7.3619564  5.05924588 3.70370827 4.39662462 4.95460696 6.94760045
#  4.78169693 4.10798628 5.17362274 4.75140504 3.56434167 5.517404
#  4.23585798 5.55817972 3.76512308 7.3102062  4.90474837 6.37362817
#  5.85622649 5.10834409 3.79568207 6.24511638 4.36326054 3.72561963
#  5.35043437 4.98801043 5.08115601 6.80017766 5.96460378 4.53921601
#  6.72648747 4.21342263 6.3583188  5.87347827 5.85676238 7.50700785
#  7.34813519 5.34891659 6.4511337  3.67269335 7.63542871 6.86342691
#  4.11200553 5.11564641 7.15769488 6.57881033 4.67480998 4.81119118] 5      7.406
# 87     5.102
# 152    3.575
# 120    4.514
# 91     5.013
# 16     6.946
# 103    4.800
# 134    4.194
# 81     5.192
# 105    4.786
# 151    3.587
# 71     5.474
# 126    4.350
# 68     5.589
# 144    3.819
# 9      7.284
# 97     4.885
# 34     6.411
# 56     5.828
# 88     5.098
# 142    3.896
# 39     6.269
# 127    4.332
# 145    3.781
# 74     5.360
# 92     5.007
# 83     5.140
# ...

# %%
#evaluating model performance
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
print('\n')
print('r2 score:',r2_score(y_test,pred))
# Out:
# error:
# Mean absolute error: 0.04578560973935841
# Mean squared error: 0.0032957848965855705
# Root Mean Squared Error: 0.05740892697643434
#
#
# r2 score: 0.9975662200058767

# %% [markdown]
# # Using other regression algorithms

# %%
#using other regression algorithms
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred=svr.predict(x_test)
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
print('\n')
print('r2 score:',r2_score(y_test,pred))
# Out:
# error:
# Mean absolute error: 0.1923378235988895
# Mean squared error: 0.07514336126580795
# Root Mean Squared Error: 0.2741228944575917
#
#
# r2 score: 0.9445102107454384

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
print('\n')
print('r2 score:',r2_score(y_test,pred))
# Out:
# error:
# Mean absolute error: 0.07495833333333334
# Mean squared error: 0.010848000000000005
# Root Mean Squared Error: 0.10415373253033232
#
#
# r2 score: 0.9919892692622018

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred=rfr.predict(x_test)
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
print('\n')
print('r2 score:',r2_score(y_test,pred))
# Out:
# error:
# Mean absolute error: 0.04013124999999959
# Mean squared error: 0.002814980741666627
# Root Mean Squared Error: 0.053056392090554245
#
#
# r2 score: 0.997921270948232

# %% [markdown]
# We are getting highest accuracy in DecisiontreeRegressor but it can be due to overfitting, so we need to check the cross_val_score then select our best model

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(lm,x2,y,scoring='r2',cv=5)
print('Cross validation score of LinearRegression model:',scr.mean())
# Out:
# Cross validation score of LinearRegression model: 0.8719959359711883

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(svr,x2,y,scoring='r2',cv=5)
print('Cross validation score of SVR:',scr.mean())
# Out:
# Cross validation score of SVR: -3.2876263852097694

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(dtr,x2,y,scoring='r2',cv=5)
print('Cross validation score of DecisionTreeRegressor:',scr.mean())
# Out:
# Cross validation score of DecisionTreeRegressor: -1.4058544007876268

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(rfr,x2,y,scoring='r2',cv=5)
print('Cross validation score of RandomForestRegressor:',scr.mean())
# Out:
# Cross validation score of RandomForestRegressor: -1.6770121278165884

# %%
#According to the above result, LinearRegression performed best.
#but significantly other regression models gave -ve cross_val_score..why this happened?????????

# %% [markdown]
# # Using Ensemble Method

# %%
from sklearn.ensemble import AdaBoostRegressor
adr=AdaBoostRegressor()
adr.fit(x_train,y_train)
adr_pred=adr.predict(x_test)
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,adr_pred))
print('Mean squared error:',mean_squared_error(y_test,adr_pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,adr_pred)))
print('\n')
print('r2 score:',r2_score(y_test,adr_pred))
# Out:
# error:
# Mean absolute error: 0.0562809670959488
# Mean squared error: 0.005718026247710592
# Root Mean Squared Error: 0.07561763185732936
#
#
# r2 score: 0.9957775102671393

# %%
from sklearn.ensemble import GradientBoostingRegressor
gdr=GradientBoostingRegressor()
gdr.fit(x_train,y_train)
gdr_pred=gdr.predict(x_test)
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,gdr_pred))
print('Mean squared error:',mean_squared_error(y_test,gdr_pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,gdr_pred)))
print('\n')
print('r2 score:',r2_score(y_test,gdr_pred))
# Out:
# error:
# Mean absolute error: 0.030296359758754287
# Mean squared error: 0.001774460760648811
# Root Mean Squared Error: 0.042124348786050224
#
#
# r2 score: 0.9986896453393855

# %%
#both adaboost and gradientboost are working well but still performance of gradientboost is slightly better...

# %% [markdown]
# # Apply Regularization method

# %%
from sklearn.linear_model import Lasso,Ridge
ls=Lasso(alpha=0.0001)
#ls=Lasso(alpha=1.0) #Default
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9943241769244726

# %%
ls.coef_
# Out:
# array([ 0.00666732, -0.01515272, -0.2857151 , -0.00585747,  0.31014624,
#         0.20974054,  0.17147818,  0.10382842,  0.07878462,  0.09965112,
#         0.40563672])

# %%
plt.figure(figsize=(22,5))
plt.bar(x2.columns,ls.coef_)
plt.show()

# %%
ls_pred=ls.predict(x_test)
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,ls_pred))
print('Mean squared error:',mean_squared_error(y_test,ls_pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,ls_pred)))
print('\n')
print('r2 score:',r2_score(y_test,ls_pred))
# Out:
# error:
# Mean absolute error: 0.04568788621605511
# Mean squared error: 0.003296147080448448
# Root Mean Squared Error: 0.05741208131089177
#
#
# r2 score: 0.997565952550364

# %%
rd=Ridge(alpha=0.0001)
#rd=Ridge
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9943246528649368

# %%
rd.coef_
# Out:
# array([ 0.00687473, -0.01571204, -0.27976139, -0.00582463,  0.31236862,
#         0.2110426 ,  0.17277969,  0.1045387 ,  0.0793515 ,  0.10043901,
#         0.40838163])

# %%
plt.figure(figsize=(22,5))
plt.bar(x2.columns,rd.coef_)
plt.show()

# %%
rd_pred=rd.predict(x_test)
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,rd_pred))
print('Mean squared error:',mean_squared_error(y_test,rd_pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rd_pred)))
print('\n')
print('r2 score:',r2_score(y_test,rd_pred))
# Out:
# error:
# Mean absolute error: 0.04578537415222931
# Mean squared error: 0.003295769966619164
# Root Mean Squared Error: 0.057408796944537724
#
#
# r2 score: 0.997566231030945

# %%
#ElasticNet is a combination of both Lasso and Ridge

from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
#enr=ElasticNet()
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)

print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,enrpred))
print('Mean squared error:',mean_squared_error(y_test,enrpred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,enrpred)))
print('\n')
print('r2 score:',r2_score(y_test,enrpred))
# Out:
# error:
# Mean absolute error: 0.045716238102662225
# Mean squared error: 0.0032965524338429224
# Root Mean Squared Error: 0.05741561141225374
#
#
# r2 score: 0.9975656532162105

# %% [markdown]
# So the r2_score of lasso,ridge and elasticnet are same and it does not differ significantly from our previously ran models interms of r2_score.
# so we can conclude that there was no such effect of overfitting and underfittlng (bias and variance) on our previous models.

# %% [markdown]
# # Saving the best model

# %% [markdown]
# Here gradientboost gives us the best r2_score so we will save this model

# %%
import joblib
joblib.dump(gdr,'gdr_model_happiness_score.obj')
# Out:
# ['gdr_model_happiness_score.obj']
